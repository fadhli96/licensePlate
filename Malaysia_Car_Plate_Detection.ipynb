# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
import uuid      # to create unique ID name
import os
import time

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\User/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2021-10-14 torch 1.8.2+cu111 CUDA:0 (NVIDIA GeForce GTX 1050, 4096.0MB)
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/.cache\torch\hub\ultralytics_yolov5_master\utils\downloads.py in safe_download(file, url, url2, min_bytes, error_msg)
#      29         print(f'Downloading {url} to {file}...')
# ---> 30         torch.hub.download_url_to_file(url, str(file))
#      31         assert file.exists() and file.stat().st_size > min_bytes, assert_msg  # check
#
# ~\anaconda3\envs\YOLO\lib\site-packages\torch\hub.py in download_url_to_file(url, dst, hash_prefix, progress)
#     413         with tqdm(total=file_size, disable=not progress,
# --> 414                   unit='B', unit_scale=True, unit_divisor=1024) as pbar:
#     415             while True:
#
# ...

# %%
IMAGES_PATH = os.path.join('data', 'images')    # Directory Folder -> data/images
labels = ['malaysia_plate']

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
# !pip install pyqt5 lxml --upgrade

# %%
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %%
# Run 'labelImg.py' software for labelling application
# !cd labelImg && python labelImg.py

# %%
# !cd yolov5 && python train.py --img 4096 --batch 16 --epochs 500 --data datasetPlate.yml --weights yolov5s.pt --workers 1
# Out:
# From https://github.com/ultralytics/yolov5
#    6b31cfd..fc36064  master     -> origin/master
# YOLOv5  2021-10-13 torch 1.8.2+cu111 CUDA:0 (NVIDIA GeForce GTX 1050, 4096.0MB)
#
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs\train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=16
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
# ...

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp2/weights/last.pt', force_reload=True)  # Load New Custom Model that we have been trained
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\User/.cache\torch\hub\master.zip
# YOLOv5  2021-10-15 torch 1.8.2+cu111 CUDA:0 (NVIDIA GeForce GTX 1050, 4096.0MB)
#
# Fusing layers...
# Model Summary: 213 layers, 7053277 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('data','images','653.jpg')

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 4096x8192 (no detections)
# Speed: 393.9ms pre-process, 20.9ms inference, 1.0ms NMS per image at shape (1, 3, 320, 640)

# %%
# %matplotlib inline
#plt.imshow(np.squeeze(results.render()))
#plt.show()

# %%
results.show()

# %%
plt.savefig('fo2o.png')
